# %%
import pandas as pd

# %%
import numpy as np

# %%
# (1) Используя параметры pandas прочитать красиво пандас (подвох что заголовки - первые 2 линии)
df = pd.read_csv('default_of_credit_card_clients.csv',sep = ';', header = 1) #TODO

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0       689         0         0         0         0
# 1      1000      1000      1000         0      2000
# 2      1500      1000      1000      1000      5000
# 3      2019      1200      1100      1069      1000
# 4     36681     10000      9000       689       679
#
#    default payment next month
# 0                           1
# 1                           1
# 2                           0
# 3                           0
# 4                           0
#
# [5 rows x 25 columns]

# %%
# (2) выведите, что за типы переменных, сколько пропусков,
# для численных значений посчитайте пару статистик (в свободной форме)

# %%
df.info()
df['BILL_AMT4'].describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# BILL_AMT6                     30000 non-null int64
# PAY_AMT1                      30000 non-null int64
# PAY_AMT2                      30000 non-null int64
# PAY_AMT3                      30000 non-null int64
# PAY_AMT4                      30000 non-null int64
# PAY_AMT5                      30000 non-null int64
# PAY_AMT6                      30000 non-null int64
# default payment next month    30000 non-null int64
# dtypes: int64(25)
# memory usage: 5.7 MB
# count     30000.000000
# mean      43262.948967
# std       64332.856134
# min     -170000.000000
# 25%        2326.750000
# 50%       19052.000000
# 75%       54506.000000
# max      891586.000000
# Name: BILL_AMT4, dtype: float64

# %%
# (3) посчитать число женщин с университетским образованием
# SEX (1 = male; 2 = female). 
# EDUCATION (1 = graduate school; 2 = university; 3 = high school; 4 = others). 
a = df[
     (df['SEX'] == 2) & (df['EDUCATION']==2)
 ]
len(a)
# Out:
# 8656

# %%
# (4) Сгрупировать по "default payment next month" и посчитать медиану для всех показателей начинающихся на BILL_ и PAY_
#TODO

#a=df.groupby('default payment next month').head(len(df))

df[[x for x in df.columns if 'BILL' in x]]
# Out:
#        BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6
# 0           3913       3102        689          0          0          0
# 1           2682       1725       2682       3272       3455       3261
# 2          29239      14027      13559      14331      14948      15549
# 3          46990      48233      49291      28314      28959      29547
# 4           8617       5670      35835      20940      19146      19131
# 5          64400      57069      57608      19394      19619      20024
# 6         367965     412023     445007     542653     483003     473944
# 7          11876        380        601        221       -159        567
# 8          11285      14096      12108      12211      11793       3719
# 9              0          0          0          0      13007      13912
# 10         11073       9787       5535       2513       1828       3731
# 11         12261      21670       9966       8517      22287      13668
# 12         12137       6500       6500       6500       6500       2870
# 13         65802      67369      65701      66782      36137      36894
# 14         70887      67060      63561      59696      56875      55512
# 15         50614      29173      28116      28771      29531      30211
# 16         15376      18010      17428      18338      17905      19104
# 17        253286     246536     194663      70074       5856     195599
# 18             0          0          0          0          0          0
# 19             0          0          0          0          0          0
# 20         38358      27688      24489      20616      11802        930
# 21           316        316        316          0        632        316
# 22         41087      42445      45020      44006      46905      46012
# 23          5512      19420       1473        560          0          0
# 24          4744       7070          0       5398       6360       8292
# 25         47620      41810      36023      28967      29829      30046
# 26          -109       -425        259        -57        127       -189
# 27         22541      16138      17163      17878      18931      19617
# 28           650       3415       3416       2040      30430        257
# 29         15329      16575      17496      17907      18375      11400
# ...          ...        ...        ...        ...        ...        ...
# 29970      33654      52686      64069      49005       8676      19487
# 29971      65554      66858      68279      69674      71070      73612
# 29972      21628      20893       5869      29223      19616     148482
# 29973          0          0          0          0          0          0
# 29974      10904       9316       4328       2846       1585       1324
# 29975      45075       8840       1369       5924       1759       1824
# 29976      52358      54892      53415      51259      47151      46934
# 29977     131939     136721     140011     141695     144839     147954
# 29978     238973     237196     233854     219409     216540     210675
# 29979          0          0          0          0          0          0
# 29980      43998      49123      49397      50360      19971      19694
# 29981      38671      36772      33101      28192      22676      14647
# 29982       7752       9112      10306      11328      12036      14329
# 29983       1822       2872       2712       2882       9235       1719
# 29984        315        923       2939       1993       1907       3319
# 29985          0          0          0          0          0          0
# 29986       2220          0          0          0          0          0
# 29987      23292      14077      15546     108047      93708      97353
# 29988     279640     252913     243075     245750     175005     179687
# 29989       3425       9009         -3        780          0          0
# 29990     138325     137142     139110     138262      49675      46121
# 29991       2500       2500       2500       2500       2500       2500
# 29992       8802      10400          0          0          0          0
# 29993       3042       1427     102996      70626      69473      55004
# 29994      72557      77708      79384      77519      82607      81158
# 29995     188948     192815     208365      88004      31237      15980
# 29996       1683       1828       3502       8979       5190          0
# 29997       3565       3356       2758      20878      20582      19357
# 29998      -1645      78379      76304      52774      11855      48944
# 29999      47929      48905      49764      36535      32428      15313
#
# [30000 rows x 6 columns]

# %%
# (6) Создать новый строковый столбец в data frame-е, который:
# принимает значение A, если значение LIMIT_BAL <=10000
# принимает значение B, если значение LIMIT_BAL <=100000 и >10000
# принимает значение C, если значение LIMIT_BAL <=200000 и >100000
# принимает значение D, если значение LIMIT_BAL <=400000 и >200000
# принимает значение E, если значение LIMIT_BAL <=700000 и >400000
# принимает значение F, если значение LIMIT_BAL >700000

#TODO

# %%
df['backet']= df['LIMIT_BAL'].map(lambda s: 'A' if s <=10000 else 'B' if s<=100000 else 'C' if s<=200000 else 'D' if s<=400000 else 'E' if s<= 700000 else 'F')
df[['backet','LIMIT_BAL']]
# Out:
#       backet  LIMIT_BAL
# 0          B      20000
# 1          C     120000
# 2          B      90000
# 3          B      50000
# 4          B      50000
# 5          B      50000
# 6          E     500000
# 7          B     100000
# 8          C     140000
# 9          B      20000
# 10         C     200000
# 11         D     260000
# 12         E     630000
# 13         B      70000
# 14         D     250000
# 15         B      50000
# 16         B      20000
# 17         D     320000
# 18         D     360000
# 19         C     180000
# 20         C     130000
# 21         C     120000
# 22         B      70000
# 23         E     450000
# 24         B      90000
# 25         B      50000
# 26         B      60000
# 27         B      50000
# 28         B      50000
# 29         B      50000
# ...      ...        ...
# 29970      D     360000
# 29971      B      80000
# 29972      C     190000
# 29973      D     230000
# 29974      B      50000
# 29975      D     220000
# 29976      B      40000
# 29977      E     420000
# 29978      D     310000
# 29979      C     180000
# 29980      B      50000
# 29981      B      50000
# 29982      B      90000
# 29983      B      20000
# 29984      B      30000
# 29985      D     240000
# 29986      D     360000
# 29987      C     130000
# 29988      D     250000
# 29989      C     150000
# 29990      C     140000
# 29991      D     210000
# 29992      A      10000
# 29993      B     100000
# 29994      B      80000
# 29995      D     220000
# 29996      C     150000
# 29997      B      30000
# 29998      B      80000
# 29999      B      50000
#
# [30000 rows x 2 columns]

# %%
# (5) постройте сводную таблицу (pivot table) по SEX, EDUCATION, MARRIAGE

pd.pivot_table(df,index = 'SEX',values = ['EDUCATION','MARRIAGE'],aggfunc=len)
# Out:
#      EDUCATION  MARRIAGE
# SEX
# 1        11888     11888
# 2        18112     18112

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# (7) постироить распределение LIMIT_BAL (гистрограмму)

# %%
df['LIMIT_BAL'].hist(bins=100) #TODO

# %%
# (8) построить зависимость кредитного лимита от образования для каждого пола
# график необходимо сделать очень широким (на весь экран)
df[['LIMIT_BAL','EDUCATION']].plot() #TODO
#tmp.set_index('timestamp').plot()

# %%
# (9) построить зависимость кредитного лимита и образования только для одного из полов

#TODO

# %%
# (10) построить большой график (подсказка - используя seaborn) для построения завимисости всех возможных пар параметров
# разным цветом выделить разные значение "default payment next month"
# (но так как столбцов много - картинка может получиться "монструозной")
# (поэкспериментируйте над тем как построить подобное сравнение параметров)
# (подсказка - ответ может состоять из несколькольких графиков)
# (если не выйдет - программа минимум - построить один график со всеми параметрами)
sns.pairplot(df,hue = 'default payment next month')

#TODO
# Out:
#   File "<ipython-input-155-2c0e21ad4013>", line 7
#     sns.pairplot??#(df,hue = 'default payment next month')
#                 ^
# SyntaxError: invalid syntax
